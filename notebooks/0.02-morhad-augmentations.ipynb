# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ails_miccai_uwf4dr_challenge.dataset import DatasetBuilder, CustomDataset, DatasetOriginationType, ChallengeTaskType
from ails_miccai_uwf4dr_challenge.preprocess_augmentations import transforms_train, transforms_val
import matplotlib.pyplot as plt
import numpy as np
from ails_miccai_uwf4dr_challenge.config import PROJ_ROOT

# %% [markdown]
# ### Original dataset

# %%
train, val = DatasetBuilder(dataset=DatasetOriginationType.ALL, task=ChallengeTaskType.TASK2, split_ratio=0.9).get_train_val()
train_data = CustomDataset(train, transform=transforms_train)
val_data = CustomDataset(val, transform=transforms_val)
# Out:
# Dataset length:  359
# Dataset length:  40

# %%
num = np.random.randint(len(train_data))
img, label = train_data[num]
print(img.shape)

# original dataset image shape: [3, 800, 1016]
# DeepDRiD dataset image shape: [3, 3072, 3900]
# Out:
# torch.Size([3, 760, 960])

# %%
num = np.random.randint(len(train_data))
img, label = train_data[num]

plt.imshow(img.permute(1,2,0))
plt.suptitle(f'Label: {int(label.item())} \n(1=good, 0=bad)')
plt.show()
